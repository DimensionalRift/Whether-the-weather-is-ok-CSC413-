# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 5.1 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 8.8 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.29)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.3 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import dataProcess

from datetime import datetime
import matplotlib.pyplot as plt
import optuna
import numpy as np

# %%
hourly = 'weatherstats_toronto_hourly.csv'
daily = 'weatherstats_toronto_daily.csv'
start = datetime(2014, 4, 16).date()
end = datetime(2024, 4, 10).date()
data = dataProcess.generateDataNoLoader(hourly, daily, start, end)
train_data = data['train']
val_data = data['validation']
test_data = data['test']

# %%
def create_dataloaders(train_data, val_data, test_data, batch_size=2048):
  train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
  val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)
  return train_loader, val_loader, test_loader

# %%
class WeatherPredictorTransformer(nn.Module):
  def __init__(self, input_size, d_model, nhead, num_encoder_layers, output_size, dropout_rate, hidden_size):
    super(WeatherPredictorTransformer, self).__init__()
    self.embedding = nn.Linear(input_size, d_model)
    self.positional_encoding = nn.Parameter(self.create_sinusoidal_positional_encoding(24, d_model), requires_grad=False)
    self.encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dropout=dropout_rate)
    self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_encoder_layers)

    self.norm1 = nn.LayerNorm(d_model)
    self.linear1 = nn.Linear(d_model, hidden_size)
    self.norm2 = nn.LayerNorm(hidden_size)
    self.linear2 = nn.Linear(hidden_size, d_model)
    self.norm3 = nn.LayerNorm(d_model)

    self.output_linear = nn.Linear(d_model, output_size)

  def forward(self, x):
    x = self.embedding(x)
    x += self.positional_encoding[:x.size(1), :]
    x = x.permute(1, 0, 2)
    encoder_output = self.transformer_encoder(x)

    x = self.norm1(encoder_output[-1])
    x = F.relu(self.linear1(x))
    x = self.norm2(x)
    x = F.relu(self.linear2(x))
    x = self.norm3(x)

    prediction = self.output_linear(x)
    return prediction

  @staticmethod
  def create_sinusoidal_positional_encoding(length, d_model):
    PE = torch.zeros(length, d_model)
    position = torch.arange(0, length, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(np.log(10000.0) / d_model))
    PE[:, 0::2] = torch.sin(position * div_term)
    PE[:, 1::2] = torch.cos(position * div_term)
    return PE

# %%
def train_model(trial, model, num_epochs, train_loader, val_loader, device):
  criterion = nn.MSELoss()
  learning_rate = trial.suggest_loguniform('lr', 1e-6, 1e-3)
  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0
    for inputs, targets in train_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      inputs, targets = inputs.float(), targets.float()
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      loss.backward()
      optimizer.step()
      total_train_loss += loss.item()

    model.eval()
    total_val_loss = 0
    with torch.no_grad():
      for inputs, targets in val_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets = inputs.float(), targets.float()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        total_val_loss += loss.item()

  avg_val_loss = total_val_loss / len(val_loader)
  return avg_val_loss

# %%
def objective(trial):
  input_size = 13
  hidden_size = trial.suggest_categorical('hidden_size', [64, 128, 256])
  d_model = trial.suggest_categorical('d_model', [64, 128, 256])
  nhead = trial.suggest_categorical('nhead', [4, 8])
  num_encoder_layers = trial.suggest_int('num_encoder_layers', 1, 4)
  dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.3)
  output_size = 1

  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  model = WeatherPredictorTransformer(input_size, d_model, nhead, num_encoder_layers, output_size, dropout_rate, hidden_size)
  model.to(device)

  train_loader, val_loader, _ = create_dataloaders(train_data, val_data, test_data)

  num_epochs = 50
  return train_model(trial, model, num_epochs, train_loader, val_loader, device)

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
for key, value in trial.params.items():
  print(f"    {key}: {value}")
# Out:
# [I 2024-04-19 05:15:42,108] A new study created in memory with name: no-name-ef58daad-9d3f-437f-82bd-7d9032f7a9f6
# <ipython-input-19-f8e2d1d80c37>:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.3)
# <ipython-input-21-8fb950ba11a1>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('lr', 1e-6, 1e-3)
# [I 2024-04-19 05:15:47,937] Trial 0 finished with value: 130.13304138183594 and parameters: {'hidden_size': 128, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.08892509752214059, 'lr': 2.7938969062789546e-05}. Best is trial 0 with value: 130.13304138183594.
# [W 2024-04-19 05:15:54,598] Trial 1 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.2682996423529428, 'lr': 0.0008622032640071223} because of the following error: The value nan is not acceptable.
# [W 2024-04-19 05:15:54,599] Trial 1 failed with value nan.
# [I 2024-04-19 05:15:57,038] Trial 2 finished with value: 168.14353942871094 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 1, 'dropout_rate': 0.19343015633335833, 'lr': 8.256451576671214e-06}. Best is trial 0 with value: 130.13304138183594.
# [I 2024-04-19 05:16:06,137] Trial 3 finished with value: 117.22113800048828 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.12585588678375623, 'lr': 6.243019913607785e-05}. Best is trial 3 with value: 117.22113800048828.
# [I 2024-04-19 05:16:11,645] Trial 4 finished with value: 176.78765869140625 and parameters: {'hidden_size': 64, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.01960055671078138, 'lr': 1.1489292805876524e-06}. Best is trial 3 with value: 117.22113800048828.
# [I 2024-04-19 05:16:14,086] Trial 5 finished with value: 142.98162841796875 and parameters: {'hidden_size': 256, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 1, 'dropout_rate': 0.21783040222888536, 'lr': 8.019648423575111e-05}. Best is trial 3 with value: 117.22113800048828.
# [I 2024-04-19 05:16:20,752] Trial 6 finished with value: 117.53746032714844 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.1456394266168346, 'lr': 3.833695369278688e-05}. Best is trial 3 with value: 117.22113800048828.
# [I 2024-04-19 05:16:26,404] Trial 7 finished with value: 122.66606140136719 and parameters: {'hidden_size': 64, 'd_model': 64, 'nhead': 8, 'num_encoder_layers': 4, 'dropout_rate': 0.23656797422044848, 'lr': 0.0005111835920139253}. Best is trial 3 with value: 117.22113800048828.
# [I 2024-04-19 05:16:29,720] Trial 8 finished with value: 129.21469116210938 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead':
ameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 1, 'dropout_rate': 0.16773777109727933, 'lr': 0.0006131123175087026} because of the following error: The value nan is not acceptable.
# [W 2024-04-19 05:20:26,540] Trial 42 failed with value nan.
# [I 2024-04-19 05:20:30,606] Trial 43 finished with value: 116.97199249267578 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 1, 'dropout_rate': 0.07962039814337495, 'lr': 8.141014904735777e-05}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:20:36,390] Trial 44 finished with value: 155.60049438476562 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.167194233812177, 'lr': 1.199327772982453e-05}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:20:45,692] Trial 45 finished with value: 116.07476043701172 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.11562674813708257, 'lr': 0.0006329112648022671}. Best is trial 30 with value: 116.03826904296875.
# [W 2024-04-19 05:20:52,561] Trial 46 failed with parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.10439516762617128, 'lr': 0.0006596520506790537} because of the following error: The value nan is not acceptable.
# [W 2024-04-19 05:20:52,563] Trial 46 failed with value nan.
# [I 2024-04-19 05:20:59,420] Trial 47 finished with value: 116.42382049560547 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.11633248024449061, 'lr': 0.0006613255364283757}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:21:01,779] Trial 48 finished with value: 166.1738739013672 and parameters: {'hidden_size': 256, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 1, 'dropout_rate': 0.15588178634699187, 'lr': 5.489291516069534e-06}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:21:10,928] Trial 49 finished with value: 116.24311065673828 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.09519774482957324, 'lr': 0.00041658869024456557}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:21:20,135] Trial 50 finished with value: 116.3122787475586 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.06970262327947346, 'lr': 0.0006322396084698878}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:21:32,085] Trial 51 finished with value: 116.26519775390625 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 4, 'dropout_rate': 0.10252169521421065, 'lr': 0.00026114039380826306}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:21:41,366] Trial 52 finished with value: 116.47897338867188 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.12479652695877225, 'lr': 0.0009913017023771087}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:21:48,131] Trial 53 finished with value: 116.7512435913086 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.03897977161802164, 'lr': 0.00016111141652517942}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:21:54,167] Trial 54 finished with value: 116.50973510742188 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.19074325682845017, 'lr': 0.0004809296161466773}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:22:00,987] Trial 55 finished with value: 116.25960540771484 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.05370687954144522, 'lr': 0.000722603632897009}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:22:09,943] Trial 56 finished with value: 117.39971923828125 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.021580593876882756, 'lr': 9.456275091993412e-05}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:22:16,063] Trial 57 finished with value: 153.5757293701172 and parameters: {'hidden_size': 64, 'd_model': 64, 'nhead': 8, 'num_encoder_layers': 4, 'dropout_rate': 0.14025447389818452, 'lr': 5.193854752643821e-05}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:22:22,816] Trial 58 finished with value: 116.11669921875 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.1206361618225795, 'lr': 0.0003545031241735138}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:22:29,554] Trial 59 finished with value: 116.39656829833984 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.11437752148378105, 'lr': 0.0003532537364675714}. Best is trial 30 with value: 116.03826904296875.
# [W 2024-04-19 05:22:36,313] Trial 60 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.10204327487941334, 'lr': 0.0005532926612995196} because of the following error: The value nan is not acceptable.
# [W 2024-04-19 05:22:36,314] Trial 60 failed with value nan.
# [I 2024-04-19 05:22:42,967] Trial 61 finished with value: 116.46133422851562 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0
. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:25:33,310] Trial 85 finished with value: 116.21273040771484 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.05921694973697624, 'lr': 0.0005756377527957131}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:25:42,352] Trial 86 finished with value: 116.24058532714844 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.12394022179575818, 'lr': 0.0008196556544061343}. Best is trial 30 with value: 116.03826904296875.
# [W 2024-04-19 05:25:51,701] Trial 87 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.08409337139784097, 'lr': 0.0003959006427982745} because of the following error: The value nan is not acceptable.
# [W 2024-04-19 05:25:51,703] Trial 87 failed with value nan.
# [I 2024-04-19 05:26:01,000] Trial 88 finished with value: 116.6113510131836 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.06798312827930342, 'lr': 0.00038218470602336356}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:26:07,727] Trial 89 finished with value: 116.53526306152344 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.07965514962701051, 'lr': 0.0004717410466173736}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:26:17,085] Trial 90 finished with value: 116.25254821777344 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.03410897601576616, 'lr': 0.000638561226445408}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:26:29,008] Trial 91 finished with value: 116.3088607788086 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 4, 'dropout_rate': 0.0993966235594992, 'lr': 0.00029264840393128193}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:26:32,499] Trial 92 finished with value: 117.02913665771484 and parameters: {'hidden_size': 64, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.08755527045419803, 'lr': 0.0009940191181639626}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:26:39,211] Trial 93 finished with value: 116.50288391113281 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.10907081318156536, 'lr': 0.0004542849073456547}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:26:45,693] Trial 94 finished with value: 116.29265594482422 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.11736654313206332, 'lr': 0.0005008429876876281}. Best is trial 30 with value: 116.03826904296875.
# [W 2024-04-19 05:26:52,377] Trial 95 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.13348029657498997, 'lr': 0.00012575899450908038} because of the following error: The value nan is not acceptable.
# [W 2024-04-19 05:26:52,378] Trial 95 failed with value nan.
# [I 2024-04-19 05:26:58,869] Trial 96 finished with value: 116.72325134277344 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.13179597200198348, 'lr': 0.0001302349302991559}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:27:05,565] Trial 97 finished with value: 116.24202728271484 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.10998306575661104, 'lr': 0.000709062143271287}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:27:12,047] Trial 98 finished with value: 116.2677993774414 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.09359577215478244, 'lr': 0.0003908476337972792}. Best is trial 30 with value: 116.03826904296875.
# [I 2024-04-19 05:27:18,901] Trial 99 finished with value: 116.27659606933594 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.07814489718981626, 'lr': 0.0003324654723107584}. Best is trial 30 with value: 116.03826904296875.
# Best trial:
#   Value: 116.03826904296875
#     hidden_size: 256
#     d_model: 256
#     nhead: 8
#     num_encoder_layers: 2
#     dropout_rate: 0.10869047580942337
#     lr: 0.0008753099356097883

# %%
'''
Best trial:
  Value: 116.03826904296875
    hidden_size: 256
    d_model: 256
    nhead: 8
    num_encoder_layers: 2
    dropout_rate: 0.10869047580942337
    lr: 0.00008753099356097883
'''

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

learning_rate = 0.00008753099356097883
num_epochs = 50

input_size = 13
d_model = 256
nhead = 8
num_encoder_layers = 2
dropout_rate = 0.10869047580942337
hidden_size = 256

output_size = 1

model = WeatherPredictorTransformer(input_size, d_model, nhead, num_encoder_layers, output_size, dropout_rate, hidden_size)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

train_loader, val_loader, test_loader = create_dataloaders(train_data, val_data, test_data)

def train_model(model, num_epochs, optimizer, criterion, train_loader, val_loader, device):
  train_losses = []
  val_losses = []

  for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0

    for inputs, targets in train_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      inputs, targets = inputs.float(), targets.float()
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      loss.backward()
      optimizer.step()
      total_train_loss += loss.item()

    avg_train_loss = total_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    model.eval()
    total_val_loss = 0
    with torch.no_grad():
      for inputs, targets in val_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets = inputs.float(), targets.float()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)

    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}')

  # Plotting
  plt.figure(figsize=(8, 6))
  plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
  plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
  plt.title('Training and Validation Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.show()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
train_model(model, num_epochs, optimizer, criterion, train_loader, val_loader, device)
# Out:
# Epoch [1/50], Training Loss: 188.7489, Validation Loss: 162.9723
# Epoch [2/50], Training Loss: 158.5843, Validation Loss: 142.1464
# Epoch [3/50], Training Loss: 135.9500, Validation Loss: 133.8383
# Epoch [4/50], Training Loss: 129.2900, Validation Loss: 129.4006
# Epoch [5/50], Training Loss: 123.0329, Validation Loss: 126.7622
# Epoch [6/50], Training Loss: 125.2383, Validation Loss: 125.0357
# Epoch [7/50], Training Loss: 128.6355, Validation Loss: 123.5644
# Epoch [8/50], Training Loss: 122.8032, Validation Loss: 122.2886
# Epoch [9/50], Training Loss: 117.4005, Validation Loss: 121.2276
# Epoch [10/50], Training Loss: 112.8932, Validation Loss: 120.3580
# Epoch [11/50], Training Loss: 121.1605, Validation Loss: 119.6212
# Epoch [12/50], Training Loss: 118.8414, Validation Loss: 118.9968
# Epoch [13/50], Training Loss: 119.8411, Validation Loss: 118.5297
# Epoch [14/50], Training Loss: 123.3519, Validation Loss: 118.1716
# Epoch [15/50], Training Loss: 121.9405, Validation Loss: 117.8679
# Epoch [16/50], Training Loss: 117.3871, Validation Loss: 117.6190
# Epoch [17/50], Training Loss: 122.8003, Validation Loss: 117.4269
# Epoch [18/50], Training Loss: 126.8001, Validation Loss: 117.2699
# Epoch [19/50], Training Loss: 105.3661, Validation Loss: 117.1318
# Epoch [20/50], Training Loss: 107.0482, Validation Loss: 117.0146
# Epoch [21/50], Training Loss: 107.5337, Validation Loss: 116.9100
# Epoch [22/50], Training Loss: 122.0175, Validation Loss: 116.8201
# Epoch [23/50], Training Loss: 113.5547, Validation Loss: 116.7495
# Epoch [24/50], Training Loss: 116.1680, Validation Loss: 116.6898
# Epoch [25/50], Training Loss: 120.3587, Validation Loss: 116.6433
# Epoch [26/50], Training Loss: 108.8372, Validation Loss: 116.5995
# Epoch [27/50], Training Loss: 111.3051, Validation Loss: 116.5538
# Epoch [28/50], Training Loss: 106.5888, Validation Loss: 116.5144
# Epoch [29/50], Training Loss: 108.8910, Validation Loss: 116.4823
# Epoch [30/50], Training Loss: 115.2789, Validation Loss: 116.4555
# Epoch [31/50], Training Loss: 117.7142, Validation Loss: 116.4355
# Epoch [32/50], Training Loss: 112.6896, Validation Loss: 116.4250
# Epoch [33/50], Training Loss: 119.9208, Validation Loss: 116.4205
# Epoch [34/50], Training Loss: 111.0941, Validation Loss: 116.4189
# Epoch [35/50], Training Loss: 118.5338, Validation Loss: 116.4163
# Epoch [36/50], Training Loss: 124.5282, Validation Loss: 116.4125
# Epoch [37/50], Training Loss: 116.5077, Validation Loss: 116.4115
# Epoch [38/50], Training Loss: 121.7265, Validation Loss: 116.4110
# Epoch [39/50], Training Loss: 115.9586, Validation Loss: 116.4101
# Epoch [40/50], Training Loss: 111.2714, Validation Loss: 116.4108
# Epoch [41/50], Training Loss: 117.9989, Validation Loss: 116.4076
# Epoch [42/50], Training Loss: 112.4879, Validation Loss: 116.4041
# Epoch [43/50], Training Loss: 107.6327, Validation Loss: 116.4045
# Epoch [44/50], Training Loss: 117.8956, Validation Loss: 116.3983
# Epoch [45/50], Training Loss: 117.0149, Validation Loss: 116.3820
# Epoch [46/50], Training Loss: 113.0142, Validation Loss: 116.3624
# Epoch [47/50], Training Loss: 113.7990, Validation Loss: 116.3472
# Epoch [48/50], Training Loss: 113.4942, Validation Loss: 116.3369
# Epoch [49/50], Training Loss: 119.2238, Validation Loss: 116.3297
# Epoch [50/50], Training Loss: 123.0138, Validation Loss: 116.3272

# %%
def evaluate_and_collect_data(model, data_loader, device):
  model.eval()
  total_mae = 0
  count = 0
  predictions = []
  actuals = []

  with torch.no_grad():
    for inputs, targets in data_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      inputs, targets = inputs.float(), targets.float()
      outputs = model(inputs)
      mae = torch.abs(outputs - targets).mean()
      total_mae += mae.item()
      count += 1

      predictions.extend(outputs.view(-1).detach().cpu().numpy())
      actuals.extend(targets.view(-1).detach().cpu().numpy())

  loss = criterion(outputs, targets)
  avg_mae = total_mae / count
  return predictions, actuals, avg_mae, loss

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

predictions, actuals, avg_mae, loss = evaluate_and_collect_data(model, test_loader, device)
print(f'Mean Prediction Error: {avg_mae:.4f}')
print(f'Loss: {loss:.4f}')
# Out:
# Mean Prediction Error: 8.3913
# Loss: 92.3799

# %%
def plot_predictions_vs_actuals(predictions, actuals):
  plt.figure(figsize=(10, 6))
  plt.plot(actuals, label='Actual Temperatures', color='blue', marker='o', linestyle='')
  plt.plot(predictions, label='Predicted Temperatures', color='red', linestyle='--', marker='x')
  plt.title('Comparison of Predicted and Actual Temperatures')
  plt.xlabel('Samples')
  plt.ylabel('Temperature')
  plt.legend()
  plt.grid(True)
  plt.show()

plot_predictions_vs_actuals(predictions, actuals)
