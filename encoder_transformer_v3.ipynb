# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 7.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 11.5 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.29)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.3 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import dataProcess

from datetime import datetime
import matplotlib.pyplot as plt
import optuna
import numpy as np

# %%
def nan_to_above(data):
  for i in range(data.shape[0]):
    for j in range(data.shape[1]):
      for k in range(data.shape[2]):
        if torch.isnan(data[i, j, k]):
          if j == 0:
            data[i, j, k] = 0
          else:
            data[i, j, k] = data[i, j-1, k]

# %%
# data preprocessing

# 2014-04-16
start = datetime(2014, 4, 16).date()
# 2024-04-11
end = datetime(2024, 4, 11).date()
hourly_path ='weatherstats_toronto_hourly.csv'
daily_path ='weatherstats_toronto_daily.csv'

# data
data_tensor_preprocess = dataProcess.dataToTensorHourly(hourly_path, separateByDay=False, missingThreshold=0.1, columnToDelete=['wind_dir', 'unixtime'], start=start, end=end)
data_tensor_preprocess_r = torch.flip(data_tensor_preprocess[0], dims=[0])

# %%
data2 = data_tensor_preprocess_r[:-7].reshape(-1, 24, 13)
data2 = data_tensor_preprocess_r[:-7]
data3 = data2.reshape(-1, 24, 13)
nan_to_above(data3)

# %%
data = data3[:, :, 1:]
print(data.shape)
print(data[0][0])
print(data[-1][-1])
# Out:
# torch.Size([3648, 24, 12])
# tensor([ 1.0011e+02,  1.0228e+02,  3.0000e+01,  2.7000e+01,  5.7000e+01,
#         -1.2400e+01, -5.1000e+00,  2.4100e+04,  0.0000e+00, -4.9000e+00,
#         -5.1000e+00,  1.0500e+02], dtype=torch.float64)
# tensor([  97.8700,   99.9300,   26.0000,    6.0000,  100.0000,   12.6000,
#           12.6000, 4800.0000,    8.0000,   12.6000,   11.3000,  101.0000],
#        dtype=torch.float64)

# %%
# targets
targets_1 = dataProcess.dailyTargets(daily_path, start=datetime(2014, 4, 17).date())
targets = torch.flip(targets_1, dims=[0])
print(targets.shape)
print(targets[0])
print(targets[-1])
# Out:
# torch.Size([3648])
# tensor(3.7500, dtype=torch.float64)
# tensor(11.1500, dtype=torch.float64)

# %%
def process_data_for_transformer(train_fraction, valid_fraction, data, targets, batch_size):

  train_dataset = TensorDataset(data, targets)
  total_size = len(data)
  train_split_point = int(total_size * train_fraction)
  valid_split_point = train_split_point + int(total_size * valid_fraction)

  train_dataset = TensorDataset(data[:train_split_point], targets[:train_split_point])
  val_dataset = TensorDataset(data[train_split_point:valid_split_point],
                              targets[train_split_point:valid_split_point])
  test_dataset = TensorDataset(data[valid_split_point:], targets[valid_split_point:])

  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
  val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  return train_loader, val_loader, test_loader

train_loader, val_loader, test_loader = process_data_for_transformer(0.6, 0.2, data, targets, 2048)

# %%
class WeatherPredictorTransformer(nn.Module):
  def __init__(self, input_size, d_model, nhead, num_encoder_layers, output_size, dropout_rate, hidden_size):
    super(WeatherPredictorTransformer, self).__init__()
    self.embedding = nn.Linear(input_size, d_model)
    self.positional_encoding = nn.Parameter(self.create_sinusoidal_positional_encoding(24, d_model), requires_grad=False)
    self.encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dropout=dropout_rate)
    self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_encoder_layers)

    self.linear1 = nn.Linear(d_model, hidden_size)
    self.linear2 = nn.Linear(hidden_size, d_model)

    self.output_linear = nn.Linear(d_model, output_size)

  def forward(self, x):
    x = self.embedding(x)
    x += self.positional_encoding[:x.size(1), :]
    x = x.permute(1, 0, 2)
    encoder_output = self.transformer_encoder(x)

    x = F.relu(self.linear1(encoder_output[-1]))
    x = F.relu(self.linear2(x))

    prediction = self.output_linear(x)
    return prediction

  @staticmethod
  def create_sinusoidal_positional_encoding(length, d_model):
      PE = torch.zeros(length, d_model)
      position = torch.arange(0, length, dtype=torch.float).unsqueeze(1)
      div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(np.log(10000.0) / d_model))
      PE[:, 0::2] = torch.sin(position * div_term)
      PE[:, 1::2] = torch.cos(position * div_term)
      return PE

# %%
def train_model(trial, model, num_epochs, train_loader, val_loader, device):
  criterion = nn.MSELoss()
  optimizer = optim.Adam(model.parameters(), lr=trial.suggest_float('lr', 1e-6, 1e-3, log=True))

  for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0
    for inputs, targets in train_loader:
      inputs, targets = inputs.to(device).float(), targets.to(device).float()
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      loss.backward()
      optimizer.step()
      total_train_loss += loss.item()

      model.eval()
      total_val_loss = 0
      with torch.no_grad():
        for inputs, targets in val_loader:
          inputs, targets = inputs.to(device).float(), targets.to(device).float()
          outputs = model(inputs)
          loss = criterion(outputs, targets)
          total_val_loss += loss.item()

  return total_val_loss / len(val_loader)

def objective(trial):
  input_size = 12 # 12
  hidden_size = trial.suggest_categorical('hidden_size', [64, 128, 256])
  d_model = trial.suggest_categorical('d_model', [64, 128, 256])
  nhead = trial.suggest_categorical('nhead', [4, 8])
  num_encoder_layers = trial.suggest_int('num_encoder_layers', 1, 4)
  dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.3)
  output_size = 1

  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  model = WeatherPredictorTransformer(input_size, d_model, nhead, num_encoder_layers, output_size, dropout_rate, hidden_size)
  model.to(device)

  num_epochs = 50
  return train_model(trial, model, num_epochs, train_loader, val_loader, device)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
for key, value in trial.params.items():
  print(f"    {key}: {value}")
# Out:
# [I 2024-04-18 23:12:36,684] A new study created in memory with name: no-name-e4603311-76cf-4017-bdb1-774ddf9d38a8
# <ipython-input-11-3f4360153855>:34: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.3)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([2048])) that is different to the input size (torch.Size([2048, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([729])) that is different to the input size (torch.Size([729, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([140])) that is different to the input size (torch.Size([140, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [I 2024-04-18 23:12:45,329] Trial 0 finished with value: 199.2838897705078 and parameters: {'hidden_size': 256, 'd_model': 64, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.23719206118379838, 'lr': 7.559164273110289e-06}. Best is trial 0 with value: 199.2838897705078.
# <ipython-input-11-3f4360153855>:34: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.3)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-04-18 23:12:54,549] Trial 1 finished with value: 195.6272430419922 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.10384339162560359, 'lr': 5.016288237700817e-06}. Best is trial 1 with value: 195.6272430419922.
# [I 2024-04-18 23:12:58,650] Trial 2 finished with value: 137.78831481933594 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 1, 'dropout_rate': 0.0627295741654431, 'lr': 0.0002742964749282187}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:13:03,127] Trial 3 finished with value: 201.24481201171875 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 1, 'dropout_rate': 0.22259608008120427, 'lr': 3.1042337987230445e-06}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:13:09,265] Trial 4 finished with value: 176.10440063476562 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 2, 'dropout_rate': 0.2859816850173528, 'lr': 2.8267625343949968e-05}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:13:18,405] Trial 5 finished with value: 147.80453491210938 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.297663318044412, 'lr': 0.0005475620375549553}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:13:31,978] Trial 6 finished with value: 141.0868377685547 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.17873324194646778, 'lr': 0.00010106616155259038}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:13:40,979] Trial 7 finished with value: 140.01870727539062 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.21308169223889487, 'lr': 0.0005716354384824518}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:13:52,070] Trial 8 finished with value: 138.2259063720703 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.027167197450581937, 'lr': 0.0003191249920993377}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:14:00,643] Trial 9 finished with value: 192.31585693359375 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.21904442188527645, 'lr': 6.4971473171630806e-06}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:14:04,178] Trial 10 finished with value: 184.39064025878906 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 8, 'num_encoder_layers': 1, 'dropout_rate': 0.007617553770279117, 'lr': 7.269285771416334e-05}. Best is trial 2 with value: 137.78831481933594.
# [I 2024-04-18 23:14:15,545] Trial 11 finished with value: 137.37168884277344 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.049511293484209074, 'lr': 0.00021369251756948914}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:14:24,208] Trial 12 finished with value: 137.72532653808594 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.07918801238520606, 'lr': 0.000179658884427542}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:14:32,596] Trial 13 finished with value: 138.7335205078125 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.11371931630643314, 'lr': 0.00011215349126406958}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:14:43,951] Trial 14 finished with value: 164.07666015625 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.07690925313603267, 'lr': 2.642191895109397e-05}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:14:52,088] Trial 15 finished with value: 139.21446228027344 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.14257075462148389, 'lr': 0.00017657360604160754}. Best is trial 11 with value: 137.37168884277344.
# [W 2024-04-18 23:15:03,429] Trial 16 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.0536510804472743, 'lr': 0.0008830924985553548} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:15:03,431] Trial 16 failed with value nan.
# [W 2024-04-18 23:15:14,721] Trial 17 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.04636545013265464, 'lr': 0.000917192139869218} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:15:14,724] Trial 17 failed with value nan.
# [I 2024-04-18 23:15:26,151] Trial 18 finished with value: 202.29295349121094 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.04962696984508506, 'lr': 1.1205800756816031e-06}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:15:36,634] Trial 19 finished with value: 155.06422424316406 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.1021590267926923, 'lr': 5.2251188342505917e-05}. Best is trial 11 with value: 137.37168884277344.
# [W 2024-04-18 23:15:50,252] Trial 20 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.14896143254921393, 'lr': 0.0009338516371325149} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:15:50,254] Trial 20 failed with value nan.
# [W 2024-04-18 23:16:02,877] Trial 21 failed with parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.1415089236209119, 'lr': 0.0009494928826780806} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:16:02,884] Trial 21 failed with value nan.
# [I 2024-04-18 23:16:14,780] Trial 22 finished with value: 181.5482177734375 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.002047055510345952, 'lr': 1.543409622708584e-05}. Best is trial 11 with value: 137.37168884277344.
# [W 2024-04-18 23:16:24,837] Trial 23 failed with parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.14618687387103868, 'lr': 0.000999936965670321} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:16:24,840] Trial 23 failed with value nan.
# [W 2024-04-18 23:16:33,522] Trial 24 failed with parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.13783848504856408, 'lr': 0.0009354610370412877} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:16:33,523] Trial 24 failed with value nan.
# [I 2024-04-18 23:16:44,402] Trial 25 finished with value: 163.95053100585938 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.14028746774200201, 'lr': 0.0009276550249418838}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:16:56,330] Trial 26 finished with value: 137.79306030273438 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.03974022878744817, 'lr': 0.0001868894869848032}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:17:02,549] Trial 27 finished with value: 139.3193359375 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 1, 'dropout_rate': 0.07510807834203065, 'lr': 0.0002888721813310638}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:17:08,968] Trial 28 finished with value: 139.40309143066406 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 8, 'num_encoder_layers': 1, 'dropout_rate': 0.061129601134204875, 'lr': 0.0002818286596485718}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:17:13,334] Trial 29 finished with value: 192.89303588867188 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 1, 'dropout_rate': 0.08598347635004361, 'lr': 4.8119986161365735e-05}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:17:17,216] Trial 30 finished with value: 155.53822326660156 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 8, 'num_encoder_layers': 1, 'dropout_rate': 0.12736113692758236, 'lr': 0.00014956669852002916}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:17:22,213] Trial 31 finished with value: 195.2694854736328 and parameters: {'hidden_size': 128, 'd_model': 64, 'nhead': 8, 'num_encoder_layers': 2, 'dropout_rate': 0.17450401240378477, 'lr': 0.0005396534440373363}. Best is trial 11 with value: 137.37168884277344.
# [I 2024-04-18 23:17:33,392] Trial 32 finished with value: 137.09463500976562 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.024501732413346057, 'lr': 0.0009629287088916666}. Best is trial 32 with value: 137.09463500976562.
# [I 2024-04-18 23:17:45,676] Trial 33 finished with value: 137.47842407226562 and parameters: {'hidden_size': 128, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 3, 'dropout_rate': 0.013498167413025307, 'lr': 0.0008457230628213829}. Best is trial 32 with value: 137.09463500976562.
# [W 2024-04-18 23:17:56,507] Trial 34 failed with parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.019265451467163117, 'lr': 0.0008791195438658116} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:17:56,509] Trial 34 failed with value nan.
# [W 2024-04-18 23:18:07,923] Trial 35 failed with parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.02004294104134337, 'lr': 0.0009362003537420641} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:18:07,925] Trial 35 failed with value nan.
# [I 2024-04-18 23:18:18,957] Trial 36 finished with value: 137.13034057617188 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.022092428611062753, 'lr': 0.0009138256792680299}. Best is trial 32 with value: 137.09463500976562.
# [I 2024-04-18 23:18:31,440] Trial 37 finished with value: 137.14837646484375 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.034154406679554064, 'lr': 0.0005328604647496681}. Best is trial 32 with value: 137.09463500976562.
# [I 2024-04-18 23:18:48,439] Trial 38 finished with value: 137.1773223876953 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.02731475951651416, 'lr': 0.000987261075222205}. Best is trial 32 with value: 137.09463500976562.
# [W 2024-04-18 23:19:02,069] Trial 39 failed with parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.027355271345894532, 'lr': 0.000884181519267501} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:19:02,071] Trial 39 failed with value nan.
# [I 2024-04-18 23:19:16,452] Trial 40 finished with value: 137.70997619628906 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.04058563003689973, 'lr': 0.0009503005203237079}. Best is trial 32 with value: 137.09463500976562.
# [W 2024-04-18 23:19:32,410] Trial 41 failed with parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.02530611902535311, 'lr': 0.000526474097060531} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:19:32,412] Trial 41 failed with value nan.
# [I 2024-04-18 23:19:46,145] Trial 42 finished with value: 137.10498046875 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.03078904374552011, 'lr': 0.0004699759280803084}. Best is trial 32 with value: 137.09463500976562.
# [I 2024-04-18 23:19:57,194] Trial 43 finished with value: 137.20362854003906 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.027504756444510614, 'lr': 0.0004490696732260635}. Best is trial 32 with value: 137.09463500976562.
# [I 2024-04-18 23:20:11,061] Trial 44 finished with value: 136.846435546875 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.020268010538238703, 'lr': 0.0004743819193235004}. Best is trial 44 with value: 136.846435546875.
# [W 2024-04-18 23:20:25,024] Trial 45 failed with parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0020835621773484386, 'lr': 0.00036995166221003787} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:20:25,027] Trial 45 failed with value nan.
# [I 2024-04-18 23:20:38,936] Trial 46 finished with value: 136.8447723388672 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.012372569806514544, 'lr': 0.0006891723498690418}. Best is trial 46 with value: 136.8447723388672.
# [I 2024-04-18 23:20:52,856] Trial 47 finished with value: 136.80271911621094 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.002218506328322583, 'lr': 0.0003886649197862368}. Best is trial 47 with value: 136.80271911621094.
# [I 2024-04-18 23:21:07,348] Trial 48 finished with value: 136.6947479248047 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.002311898267633141, 'lr': 0.000408900343838669}. Best is trial 48 with value: 136.6947479248047.
# [I 2024-04-18 23:21:16,439] Trial 49 finished with value: 142.68276977539062 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.2533193990184985, 'lr': 0.00035445190008320126}. Best is trial 48 with value: 136.6947479248047.
# [I 2024-04-18 23:21:30,762] Trial 50 finished with value: 136.78492736816406 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0034272743708116567, 'lr': 0.00011338164548388981}. Best is trial 48 with value: 136.6947479248047.
# [I 2024-04-18 23:21:39,758] Trial 51 finished with value: 148.1700439453125 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.004270912219338183, 'lr': 0.0001128059941393355}. Best is trial 48 with value: 136.6947479248047.
# [I 2024-04-18 23:21:53,306] Trial 52 finished with value: 137.76048278808594 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0018196157517522977, 'lr': 0.0003657736385765865}. Best is trial 48 with value: 136.6947479248047.
# [I 2024-04-18 23:22:07,396] Trial 53 finished with value: 139.22055053710938 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.05725425131798275, 'lr': 0.0006472880996824684}. Best is trial 48 with value: 136.6947479248047.
# [I 2024-04-18 23:22:21,089] Trial 54 finished with value: 141.01918029785156 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.013861032971668909, 'lr': 8.11457096345471e-05}. Best is trial 48 with value: 136.6947479248047.
# [I 2024-04-18 23:22:34,953] Trial 55 finished with value: 136.46597290039062 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.016639446249411334, 'lr': 0.0002358787962169204}. Best is trial 55 with value: 136.46597290039062.
# [I 2024-04-18 23:22:48,827] Trial 56 finished with value: 137.49095153808594 and parameters: {'hidden_size': 256, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.044552484809426904, 'lr': 0.00024001729214004791}. Best is trial 55 with value: 136.46597290039062.
# [I 2024-04-18 23:23:02,546] Trial 57 finished with value: 142.10113525390625 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.00019153286072806858, 'lr': 0.00013513811003112335}. Best is trial 55 with value: 136.46597290039062.
# [I 2024-04-18 23:23:11,867] Trial 58 finished with value: 136.18292236328125 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.014809447772472081, 'lr': 0.00023132400748421473}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:23:20,916] Trial 59 finished with value: 150.36151123046875 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.18900458533225548, 'lr': 7.301525236749405e-05}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:23:29,926] Trial 60 finished with value: 136.82566833496094 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0644812478342277, 'lr': 0.00021233268071676917}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:23:39,653] Trial 61 finished with value: 177.53578186035156 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0979986732662, 'lr': 1.9246617078552907e-05}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:23:48,808] Trial 62 finished with value: 137.5958251953125 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0686312355097681, 'lr': 0.00022300704357893698}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:23:58,243] Trial 63 finished with value: 138.1456756591797 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.04948588282402412, 'lr': 0.00014493756125663303}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:24:07,149] Trial 64 finished with value: 136.83383178710938 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.015837764823333857, 'lr': 0.00033708672029264145}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:24:16,906] Trial 65 finished with value: 164.26052856445312 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.03753851370740974, 'lr': 9.575003019004696e-05}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:24:26,314] Trial 66 finished with value: 137.2521209716797 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.05408736816126801, 'lr': 0.0002223366126833621}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:24:35,493] Trial 67 finished with value: 174.2137908935547 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0003640064287502246, 'lr': 3.8768295103078617e-05}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:24:44,763] Trial 68 finished with value: 136.662841796875 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.016313748841145222, 'lr': 0.0001644276835534966}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:24:53,743] Trial 69 finished with value: 200.97650146484375 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.014525602429669666, 'lr': 3.265087985237134e-06}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:25:07,511] Trial 70 finished with value: 155.0394744873047 and parameters: {'hidden_size': 64, 'd_model': 256, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.08884797064506787, 'lr': 5.338363837239595e-05}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:25:14,860] Trial 71 finished with value: 154.27687072753906 and parameters: {'hidden_size': 256, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.2556913184439095, 'lr': 0.0001616577325439949}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:25:24,287] Trial 72 finished with value: 136.74293518066406 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.0325784515651325, 'lr': 0.0002763514729141516}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:25:33,603] Trial 73 finished with value: 136.52516174316406 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.011084094865258515, 'lr': 0.00026705815188808905}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:25:42,642] Trial 74 finished with value: 136.69656372070312 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.031004278893822287, 'lr': 0.0002830770351236397}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:25:52,020] Trial 75 finished with value: 136.8734130859375 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.033482890140368995, 'lr': 0.000281540264733347}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:26:01,188] Trial 76 finished with value: 136.88609313964844 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.019984488879137494, 'lr': 0.0002685854636187469}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:26:08,683] Trial 77 finished with value: 189.0129852294922 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.04273042316559063, 'lr': 9.593420887069525e-06}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:26:18,106] Trial 78 finished with value: 137.13270568847656 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.03150608904922926, 'lr': 0.0006861481305063434}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:26:26,122] Trial 79 finished with value: 136.75015258789062 and parameters: {'hidden_size': 256, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.04930496438709101, 'lr': 0.00018727090942252358}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:26:35,511] Trial 80 finished with value: 136.3374481201172 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.023471835956131035, 'lr': 0.00042310008616362586}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:26:44,282] Trial 81 finished with value: 148.2100067138672 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.022505990587946216, 'lr': 0.00013018038344974795}. Best is trial 58 with value: 136.18292236328125.
# [I 2024-04-18 23:26:53,558] Trial 82 finished with value: 136.09820556640625 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.011038123677357257, 'lr': 0.000373939857780409}. Best is trial 82 with value: 136.09820556640625.
# [I 2024-04-18 23:27:03,253] Trial 83 finished with value: 136.33509826660156 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.01417764505189803, 'lr': 0.0004311273327405181}. Best is trial 82 with value: 136.09820556640625.
# [I 2024-04-18 23:27:12,451] Trial 84 finished with value: 136.02870178222656 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.01288870138137699, 'lr': 0.000403262997929735}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:27:21,542] Trial 85 finished with value: 136.62521362304688 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.011993685502528233, 'lr': 0.0005510242007500412}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:27:30,726] Trial 86 finished with value: 136.11422729492188 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.011304395731897557, 'lr': 0.000583728034509924}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:27:40,133] Trial 87 finished with value: 136.7989044189453 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.009240253105282358, 'lr': 0.0007745320744785011}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:27:49,352] Trial 88 finished with value: 136.7686309814453 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.021954760781201163, 'lr': 0.0005673070106178694}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:27:58,433] Trial 89 finished with value: 136.87313842773438 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.04192183668807519, 'lr': 0.00042213333885741185}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:28:06,273] Trial 90 finished with value: 202.48338317871094 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 3, 'dropout_rate': 0.12274469758311946, 'lr': 1.370930430518969e-06}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:28:15,433] Trial 91 finished with value: 169.37362670898438 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.1580068784625583, 'lr': 0.0003546107522787953}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:28:24,719] Trial 92 finished with value: 136.58633422851562 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.010456542112712132, 'lr': 0.0004944153645975187}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:28:33,548] Trial 93 finished with value: 136.7930908203125 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.010037718158617998, 'lr': 0.0006577697238033681}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:28:42,807] Trial 94 finished with value: 136.490478515625 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.022596683561074554, 'lr': 0.0004605204602558424}. Best is trial 84 with value: 136.02870178222656.
# [W 2024-04-18 23:28:52,118] Trial 95 failed with parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.024744166975802222, 'lr': 0.0007742080401976114} because of the following error: The value nan is not acceptable.
# [W 2024-04-18 23:28:52,120] Trial 95 failed with value nan.
# [I 2024-04-18 23:29:01,163] Trial 96 finished with value: 136.41624450683594 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.02474296070870044, 'lr': 0.00040843804447972053}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:29:10,328] Trial 97 finished with value: 136.2784423828125 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.020720873174583907, 'lr': 0.0004149705652031196}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:29:20,328] Trial 98 finished with value: 136.850830078125 and parameters: {'hidden_size': 64, 'd_model': 128, 'nhead': 8, 'num_encoder_layers': 4, 'dropout_rate': 0.02801301771371681, 'lr': 0.0007887712708474113}. Best is trial 84 with value: 136.02870178222656.
# [I 2024-04-18 23:29:27,962] Trial 99 finished with value: 140.7108917236328 and parameters: {'hidden_size': 64, 'd_model': 64, 'nhead': 4, 'num_encoder_layers': 4, 'dropout_rate': 0.04680441299080219, 'lr': 0.00032549213296710606}. Best is trial 84 with value: 136.02870178222656.
# Best trial:
#   Value: 136.02870178222656
#     hidden_size: 64
#     d_model: 128
#     nhead: 4
#     num_encoder_layers: 4
#     dropout_rate: 0.01288870138137699
#     lr: 0.000403262997929735

# %%
'''
Best trial:
  Value: 136.02870178222656
    hidden_size: 64
    d_model: 128
    nhead: 4
    num_encoder_layers: 4
    dropout_rate: 0.01288870138137699
    lr: 0.000403262997929735
'''

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

learning_rate = 0.00040326
num_epochs = 50

input_size = 12
d_model = 128
nhead = 4
num_encoder_layers = 4
dropout_rate = 0.012889
hidden_size = 64

output_size = 1

model = WeatherPredictorTransformer(input_size, d_model, nhead, num_encoder_layers, output_size, dropout_rate, hidden_size)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

def train_model(model, num_epochs, optimizer, criterion, train_loader, val_loader):
  train_losses = []
  val_losses = []

  for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0

    for inputs, targets in train_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      inputs, targets = inputs.float(), targets.float()
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      loss.backward()
      optimizer.step()
      total_train_loss += loss.item()

    avg_train_loss = total_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    model.eval()
    total_val_loss = 0
    with torch.no_grad():
      for inputs, targets in val_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets = inputs.float(), targets.float()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)

    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}')

  # Plotting
  plt.figure(figsize=(8, 6))
  plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
  plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
  plt.title('Training and Validation Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.show()

train_model(model, num_epochs, optimizer, criterion, train_loader, val_loader)
# Out:
# Epoch [1/50], Training Loss: 117.7378, Validation Loss: 202.5318
# Epoch [2/50], Training Loss: 115.2458, Validation Loss: 198.1467
# Epoch [3/50], Training Loss: 113.0666, Validation Loss: 194.3795
# Epoch [4/50], Training Loss: 111.2280, Validation Loss: 191.3095
# Epoch [5/50], Training Loss: 109.7606, Validation Loss: 188.8252
# Epoch [6/50], Training Loss: 108.5946, Validation Loss: 186.6532
# Epoch [7/50], Training Loss: 107.5948, Validation Loss: 184.7196
# Epoch [8/50], Training Loss: 106.7224, Validation Loss: 182.8311
# Epoch [9/50], Training Loss: 105.8858, Validation Loss: 180.8605
# Epoch [10/50], Training Loss: 105.0306, Validation Loss: 178.8134
# Epoch [11/50], Training Loss: 104.1565, Validation Loss: 176.7832
# Epoch [12/50], Training Loss: 103.3157, Validation Loss: 174.6340
# Epoch [13/50], Training Loss: 102.4428, Validation Loss: 172.5489
# Epoch [14/50], Training Loss: 101.6196, Validation Loss: 170.4090
# Epoch [15/50], Training Loss: 100.8047, Validation Loss: 168.2189
# Epoch [16/50], Training Loss: 99.9907, Validation Loss: 166.0170
# Epoch [17/50], Training Loss: 99.2056, Validation Loss: 163.8608
# Epoch [18/50], Training Loss: 98.4692, Validation Loss: 161.6952
# Epoch [19/50], Training Loss: 97.7518, Validation Loss: 159.5757
# Epoch [20/50], Training Loss: 97.0924, Validation Loss: 157.4882
# Epoch [21/50], Training Loss: 96.4733, Validation Loss: 155.3853
# Epoch [22/50], Training Loss: 95.8889, Validation Loss: 153.3326
# Epoch [23/50], Training Loss: 95.3524, Validation Loss: 151.3722
# Epoch [24/50], Training Loss: 94.8682, Validation Loss: 149.5310
# Epoch [25/50], Training Loss: 94.4556, Validation Loss: 147.7972
# Epoch [26/50], Training Loss: 94.1013, Validation Loss: 146.1908
# Epoch [27/50], Training Loss: 93.8011, Validation Loss: 144.7086
# Epoch [28/50], Training Loss: 93.5428, Validation Loss: 143.3523
# Epoch [29/50], Training Loss: 93.3458, Validation Loss: 142.1238
# Epoch [30/50], Training Loss: 93.1782, Validation Loss: 141.0230
# Epoch [31/50], Training Loss: 93.0454, Validation Loss: 140.0474
# Epoch [32/50], Training Loss: 92.9465, Validation Loss: 139.1922
# Epoch [33/50], Training Loss: 92.8587, Validation Loss: 138.4522
# Epoch [34/50], Training Loss: 92.7895, Validation Loss: 137.8199
# Epoch [35/50], Training Loss: 92.7625, Validation Loss: 137.2868
# Epoch [36/50], Training Loss: 92.7341, Validation Loss: 136.8446
# Epoch [37/50], Training Loss: 92.7010, Validation Loss: 136.4837
# Epoch [38/50], Training Loss: 92.6878, Validation Loss: 136.1954
# Epoch [39/50], Training Loss: 92.6671, Validation Loss: 135.9716
# Epoch [40/50], Training Loss: 92.6436, Validation Loss: 135.8034
# Epoch [41/50], Training Loss: 92.6302, Validation Loss: 135.6829
# Epoch [42/50], Training Loss: 92.6311, Validation Loss: 135.6036
# Epoch [43/50], Training Loss: 92.6223, Validation Loss: 135.5590
# Epoch [44/50], Training Loss: 92.6183, Validation Loss: 135.5425
# Epoch [45/50], Training Loss: 92.6112, Validation Loss: 135.5489
# Epoch [46/50], Training Loss: 92.5920, Validation Loss: 135.5734
# Epoch [47/50], Training Loss: 92.6002, Validation Loss: 135.6116
# Epoch [48/50], Training Loss: 92.5943, Validation Loss: 135.6602
# Epoch [49/50], Training Loss: 92.5865, Validation Loss: 135.7166
# Epoch [50/50], Training Loss: 92.5762, Validation Loss: 135.7765

# %%
def evaluate_and_collect_data(model, data_loader, device):
  model.eval()
  total_mae = 0
  count = 0
  predictions = []
  actuals = []

  with torch.no_grad():
    for inputs, targets in data_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      inputs, targets = inputs.float(), targets.float()
      outputs = model(inputs)
      mae = torch.abs(outputs - targets).mean()
      total_mae += mae.item()
      count += 1

      predictions.extend(outputs.view(-1).detach().cpu().numpy())
      actuals.extend(targets.view(-1).detach().cpu().numpy())


  avg_mae = total_mae / count
  return predictions, actuals, avg_mae

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

predictions, actuals, avg_mae = evaluate_and_collect_data(model, test_loader, device)
print(f'Mean Prediction Error: {avg_mae:.4f}')
# Out:
# Mean Prediction Error: 8.9250

# %%
def plot_predictions_vs_actuals(predictions, actuals):
  plt.figure(figsize=(10, 6))
  plt.plot(actuals, label='Actual Temperatures', color='blue', marker='o', linestyle='')
  plt.plot(predictions, label='Predicted Temperatures', color='red', linestyle='--', marker='x')
  plt.title('Comparison of Predicted and Actual Temperatures')
  plt.xlabel('Samples')
  plt.ylabel('Temperature')
  plt.legend()
  plt.grid(True)
  plt.show()

plot_predictions_vs_actuals(predictions, actuals)
